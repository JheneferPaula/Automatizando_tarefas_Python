# %% [markdown]
# # Problema
# - Passo 1: buscar dados dos valores das ações de forma automática no site  do Yahoo Finanças
# - Passo 2: gerar as análises solicitadas pelo gestor de froma automática
# - Passo 3: enviar im email automaticamente para o gestor com resultados das análises

# %% [markdown]
# # Passo 1

# %%
# !pip install yfinance

# %%
import yfinance

# %%
ticker = input("digite a sigla da ação desejata: ")
dados = yfinance.Ticker("ABEV3.SA").history("6mo")
fechamento = dados.Close
fechamento.plot()
# Out:
# digite a sigla da ação desejata: PETR4.SA
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Passo 2
# Análises dos últimos 6 meses:
# - Cotação máxima
# - Cotação minima
# - Cotação atual

# %%
maxima = fechamento.max()
minima = fechamento.min()
atual = fechamento[-1]
# Out:
# 16.0

# %% [markdown]
# # Passo 3
# - abrir uma nova aba e digitar o endereço do gmail
# - clicar no botão Escrever
# - preencher o email do destinatário
# - preencher o assunto
# - escrever o email
# - clicar em enviar

# %%
# !pip install pyautogui

# %%
# !pip install pyperclip

# %%
import pyperclip
import pyautogui

# %%
pyautogui.PAUSE = 2

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")
pyautogui.click(x=593, y=176)

pyperclip.copy("jhenefer.paula@icloud.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

pyperclip.copy("Análises diárias")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

mensagem = f"""
Prezado Gestor,

seguem as análises dos últimos seis meses da ação {ticker}:

Cotação máxima: R$ {round(maxima, 2)}
Cotação mínima: R$ {round(minima, 2)}
Cotação atual: R$ {round(atual, 2)}

Estou à disposição!
Att
"""

pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")
    
pyautogui.click(x=1252, y=1005)

# %%
import time

time.sleep(5)
print("teste")
pyautogui.position()
# Out:
# teste
# Point(x=1252, y=1005)
